# %% [markdown]
# <a href="https://colab.research.google.com/github/denverkim/eyesvision/blob/main/%EC%9E%AC%ED%85%8C%ED%81%AC%EC%8B%A4%EC%8A%B53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
# ▶ 사전 설치 필요: yfinance
# 터미널에서 아래 명령어로 설치
# pip install yfinance

import yfinance as yf

# 삼성전자 종목 코드: '005930.KS' (Yahoo Finance 기준)
samsung = yf.download("005930.KS", start="2023-01-01", end="2025-09-25")

# 최근 5일 데이터 출력
print(samsung.tail())
# Out:
# /tmp/ipython-input-1005889659.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   samsung = yf.download("005930.KS", start="2023-01-01", end="2025-09-25")
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open    Volume
# Ticker     005930.KS 005930.KS 005930.KS 005930.KS 005930.KS
# Date
# 2025-09-17   78200.0   79100.0   77100.0   79100.0  20856317
# 2025-09-18   80300.0   80500.0   78600.0   79100.0  25619035
# 2025-09-22   83500.0   84000.0   81100.0   81500.0  27529656
# 2025-09-23   84700.0   85900.0   83600.0   85800.0  23610263
# 2025-09-24   85400.0   85500.0   83700.0   84200.0  18300997

# %%
samsung
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker         005930.KS     005930.KS     005930.KS     005930.KS 005930.KS
# Date
# 2023-01-02  52576.949219  53145.348670  52292.749493  52576.949219  10031448
# 2023-01-03  52482.222656  53050.622180  51629.623371  52482.222656  13547030
# 2023-01-04  54755.824219  54945.290739  52671.692501  52766.425761  20188071
# 2023-01-05  55134.757812  55703.157378  54566.358247  55134.757812  15682826
# 2023-01-06  55892.613281  56271.546253  54850.547610  55229.480581  17334989
# ...                  ...           ...           ...           ...       ...
# 2025-09-17  78200.000000  79100.000000  77100.000000  79100.000000  20856317
# 2025-09-18  80300.000000  80500.000000  78600.000000  79100.000000  25619035
# 2025-09-22  83500.000000  84000.000000  81100.000000  81500.000000  27529656
# 2025-09-23  84700.000000  85900.000000  83600.000000  85800.000000  23610263
# ...

# %%
#선그래프
import matplotlib.pyplot as plt
plt.plot(samsung['Close'])
plt.show()
